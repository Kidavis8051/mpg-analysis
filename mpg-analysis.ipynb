# %%
import seaborn as sns

# %%
mpg = sns.load_dataset("mpg")

# %% [markdown]
# #### *mpg (miles per gallon, a measure of fuel economy)*

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# #### *Create a visual showing the relationship between horsepower and fuel economy.*

# %%
# Create a visual showing the relationship between horsepower and fuel economy.
sns.scatterplot(data=mpg, x='horsepower', y='mpg')
plt.title('Relationship between Horsepower and Fuel Economy (mpg)')
plt.xlabel('Horsepower')
plt.ylabel('Miles per Gallon (Fuel Economy)')
plt.show()

# %% [markdown]
# #### In general, cars with higher horsepower have lower fuel economy (lower mpg).
# #### There's a negative relationship: as horsepower increases, mpg decreases.
# #### Some cars with very low horsepower can achieve very high fuel economy.

# %% [markdown]
# #### *Create a table summarizing fuel economy by country of origin*

# %%
# Group the data by 'origin' and calculate the mean fuel economy
mpg_summary = mpg.groupby('origin')['mpg'].agg(['count', 'mean', 'median']).reset_index()

# Display the summary table
mpg_summary
# Out:
#    origin  count       mean  median
# 0  europe     70  27.891429    26.5
# 1   japan     79  30.450633    31.6
# 2     usa    249  20.083534    18.5

# %% [markdown]
# #### Japanese cars have the highest average fuel economy (mpg).
# #### European cars are in the middle.
# #### American cars have the lowest average mpg — they tend to be bigger and have more powerful engines.
# #### USA also has the most cars in the dataset.

# %% [markdown]
# #### *Create a visual showing how fuel economy has changed over time*

# %%
# Use seaborn's theme for better visuals
sns.set_theme(style="whitegrid")

# Create a line plot: model_year vs avg mpg
sns.lineplot(data=mpg, x='model_year', y='mpg', estimator='mean', errorbar=None)

# Add titles and labels
plt.title('Fuel Economy Over Time')
plt.xlabel('Model Year')
plt.ylabel('Average Miles per Gallon (mpg)')

plt.show()

# %% [markdown]
# #### Fuel economy generally increased over time from 1970 to 1982.
# #### Big jumps happened during the mid-late 1970s — possibly due to oil crises and stricter regulations.
# #### Newer model years tend to have more efficient cars.

# %% [markdown]
# #### *Create two other visuals or tables related to fuel economy*

# %%
# Boxplot of fuel economy by origin
sns.boxplot(data=mpg, x='origin', y='mpg')

# Add titles and labels
plt.title('Fuel Economy Distribution by Country of Origin')
plt.xlabel('Country of Origin')
plt.ylabel('Miles per Gallon (mpg)')

plt.show()

# %% [markdown]
# #### Japanese cars usually have higher mpg and less variation.
# #### U.S. cars have a wider spread (some very low mpg vehicles).
# #### European cars are in between.

# %%
# Scatterplot of fuel economy vs weight
sns.scatterplot(data=mpg, x='weight', y='mpg')

# Add titles and labels
plt.title('Fuel Economy vs Vehicle Weight')
plt.xlabel('Vehicle Weight')
plt.ylabel('Miles per Gallon (mpg)')

plt.show()

# %% [markdown]
# #### Heavier vehicles tend to have lower fuel economy (negative correlation).
# #### Lighter vehicles usually achieve better mpg.
# #### There's a clear trend: lighter = more efficient.
